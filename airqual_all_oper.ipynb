# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("AirQuality.csv")
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         37
# Solar.R        7
# Wind           0
# Temp           0
# Month          0
# Day            0
# dtype: int64

# %%
## DATA CLEANING ##

df['Ozone']=df['Ozone'].replace(to_replace = np.NaN, value = '12')

# %%
df
# Out:
#      Unnamed: 0 Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1  41.0    190.0   7.4    67      5    1
# 1             2  36.0    118.0   8.0    72      5    2
# 2             3  12.0    149.0  12.6    74      5    3
# 3             4  18.0    313.0  11.5    62      5    4
# 4             5    12      NaN  14.3    56      5    5
# ..          ...   ...      ...   ...   ...    ...  ...
# 148         149  30.0    193.0   6.9    70      9   26
# 149         150    12    145.0  13.2    77      9   27
# 150         151  14.0    191.0  14.3    75      9   28
# 151         152  18.0    131.0   8.0    76      9   29
# 152         153  20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
df['Solar.R']=df['Solar.R'].replace(to_replace = np.NaN, value = '14')

# %%
df
# Out:
#      Unnamed: 0 Ozone Solar.R  Wind  Temp  Month  Day
# 0             1  41.0   190.0   7.4    67      5    1
# 1             2  36.0   118.0   8.0    72      5    2
# 2             3  12.0   149.0  12.6    74      5    3
# 3             4  18.0   313.0  11.5    62      5    4
# 4             5    12      14  14.3    56      5    5
# ..          ...   ...     ...   ...   ...    ...  ...
# 148         149  30.0   193.0   6.9    70      9   26
# 149         150    12   145.0  13.2    77      9   27
# 150         151  14.0   191.0  14.3    75      9   28
# 151         152  18.0   131.0   8.0    76      9   29
# 152         153  20.0   223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
df.isnull().sum()  //no NULL VALUES
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       0
# Wind          0
# Temp          0
# Month         0
# Day           0
# dtype: int64

# %%
## DATA INTEGRATION ##

df1=df[['Ozone','Solar.R']].loc[0:15]
df1
# Out:
#    Ozone Solar.R
# 0   41.0   190.0
# 1   36.0   118.0
# 2   12.0   149.0
# 3   18.0   313.0
# 4     12      14
# 5   28.0      14
# 6   23.0   299.0
# 7   19.0    99.0
# 8    8.0    19.0
# 9     12   194.0
# 10   7.0      14
# 11  16.0   256.0
# 12  11.0   290.0
# 13  14.0   274.0
# 14  18.0    65.0
# 15  14.0   334.0

# %%
df2=df[['Ozone','Solar.R']].loc[16:30]
df2
# Out:
#     Ozone Solar.R
# 16   34.0   307.0
# 17    6.0    78.0
# 18   30.0   322.0
# 19   11.0    44.0
# 20    1.0     8.0
# 21   11.0   320.0
# 22    4.0    25.0
# 23   32.0    92.0
# 24     12    66.0
# 25     12   266.0
# 26     12      14
# 27   23.0    13.0
# 28   45.0   252.0
# 29  115.0   223.0
# 30   37.0   279.0

# %%
a= pd.concat([df1,df2])
a
# Out:
#     Ozone Solar.R
# 0    41.0   190.0
# 1    36.0   118.0
# 2    12.0   149.0
# 3    18.0   313.0
# 4      12      14
# 5    28.0      14
# 6    23.0   299.0
# 7    19.0    99.0
# 8     8.0    19.0
# 9      12   194.0
# 10    7.0      14
# 11   16.0   256.0
# 12   11.0   290.0
# 13   14.0   274.0
# 14   18.0    65.0
# 15   14.0   334.0
# 16   34.0   307.0
# 17    6.0    78.0
# 18   30.0   322.0
# 19   11.0    44.0
# 20    1.0     8.0
# 21   11.0   320.0
# 22    4.0    25.0
# 23   32.0    92.0
# 24     12    66.0
# 25     12   266.0
# 26     12      14
# 27   23.0    13.0
# 28   45.0   252.0
# 29  115.0   223.0
# 30   37.0   279.0

# %%
## ERROR CORRECTING ##

df1[df1['ca']==4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 ## ERROR CORRECTING ##
# ----> 3 df1[df1['ca']==4]
#
# TypeError: list indices must be integers or slices, not str

# %%
## MODEL BUILDING ##

from sklearn import preprocessing
lb = preprocessing.LabelEncoder()
df['Month'] = lb.fit_transform(df['Month'])
df
# Out:
#      Unnamed: 0 Ozone Solar.R  Wind  Temp  Month  Day
# 0             1  41.0   190.0   7.4    67      0    1
# 1             2  36.0   118.0   8.0    72      0    2
# 2             3  12.0   149.0  12.6    74      0    3
# 3             4  18.0   313.0  11.5    62      0    4
# 4             5    12      14  14.3    56      0    5
# ..          ...   ...     ...   ...   ...    ...  ...
# 148         149  30.0   193.0   6.9    70      4   26
# 149         150    12   145.0  13.2    77      4   27
# 150         151  14.0   191.0  14.3    75      4   28
# 151         152  18.0   131.0   8.0    76      4   29
# 152         153  20.0   223.0  11.5    68      4   30
#
# [153 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size = 0.3, random_state = 30)

# %%
x_train.shape, x_test.shape, y_train.shape
# Out:
# ((107, 6), (46, 6), (107,))

# %%
from sklearn.naive_bayes import GaussianNB
g = GaussianNB()
g.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = g.predict(x_test)
y_pred
# Out:
# array([11, 23, 15, 18, 23,  1, 18, 26, 15,  7, 11,  5, 31, 27,  1, 26,  9,
#        16, 30, 24,  9, 31, 26,  9, 24, 26, 23, 11, 26, 15, 26,  4,  7, 31,
#         2, 30, 26,  9, 12,  2, 23,  6, 23, 18, 15, 27])

# %%
from sklearn.metrics import accuracy_score
print("Acc : {0:0.4f}", format(accuracy_score(y_test, y_pred)))
# Out:
# Acc : {0:0.4f} 0.0

# %%
## VISULIZATION ##
## BOX PLOT

a = df.boxplot(column='Wind', by='Temp',figsize=(8,4))
a.set_ylabel('Wind')
a.set_xlabel('Temp')
a
# Out:
# <AxesSubplot: title={'center': 'Wind'}, xlabel='Temp', ylabel='Wind'>

# %%
sns.lineplot(x='Wind', y='Temp', data=df)
plt.show()

# %%
sns.scatterplot(x='Wind',y='Temp', data=df)
plt.show()

# %%
df5=df[['Day','Temp']].loc[0:10]
df5
# Out:
#     Day  Temp
# 0     1    67
# 1     2    72
# 2     3    74
# 3     4    62
# 4     5    56
# 5     6    66
# 6     7    65
# 7     8    59
# 8     9    61
# 9    10    69
# 10   11    74

# %%
Days='Day'
plt.bar('Day','Temp', data=df)
plt.xlabel('Days')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 3
#       1 Days='Day'
#       2 plt.bar('Day','Temp', data=df)
# ----> 3 plt.xlabel('Days')
#       4 plt.show()
#
# TypeError: 'str' object is not callable

# %%
correlation_matrix = df.corr()

# Plot the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', square=True)

# Add title and display the plot
plt.title('Correlation Matrix of Air Quality Dataset')
plt.show()
